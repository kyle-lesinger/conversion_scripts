# %% [markdown]
# # Enhanced S3 to COG Converter with Automatic AWS Authentication
#
# This notebook converts TIF files from S3 to Cloud Optimized GeoTIFFs (COGs) with:
# - **Automatic AWS credential detection** (no .env file needed)
# - **Download caching** to avoid re-downloading large files
# - **COG validation** before uploading
#
# Author: Kyle Lesinger (Enhanced version)

# %%
import os
import pandas as pd
import json
import tempfile
import boto3
import rasterio
import rioxarray as rxr
import s3fs
import fsspec
from rasterio.warp import calculate_default_transform, reproject, Resampling
from botocore.exceptions import NoCredentialsError, ClientError
from pathlib import Path
from datetime import datetime
import time

print("✅ Libraries imported successfully!")
print(f"Boto3 version: {boto3.__version__}")
# Out:
# ✅ Libraries imported successfully!
# Boto3 version: 1.37.3

# %%
# Add path for importing custom modules
import sys
from pathlib import Path

# Add the scripts directory to the Python path
scripts_dir = Path('../scripts').resolve()
if str(scripts_dir) not in sys.path:
    sys.path.insert(0, str(scripts_dir))

# Import functions from list_s3crawler_files module
from list_s3crawler_files import (
    load_drcs_data,
    get_tif_files_from_path,
    get_files_with_full_paths,
    list_available_directories
)

# Import COG and cache utilities
from cog_utilities import (
    check_cache_status,
    clear_cache,
    validate_cog
)

# Import AWS S3 utilities
from aws_s3_utils import (
    initialize_s3_client,
    verify_s3_client,
    get_all_s3_keys
)

# Import batch processing utilities
from batch_processing import (
    process_file_batch,
    print_batch_summary
)

print("✅ Custom modules imported successfully!")
print(f"   Module path: {scripts_dir}")
# Out:
# ✅ Custom modules imported successfully!
#    Module path: /home/jovyan/conversion_scripts/convert-files-and-move/scripts

# %% [markdown]
# # Useful links
# <a href="https://data.disasters.openveda.cloud/browseui/browseui/#drcs_activations/" style="color: blue; font-size: 20px;">drcs_activations OLD Directory</a> -- You can view old directory file structure here.
#
# <a href="https://docs.openveda.cloud/user-guide/content-curation/dataset-ingestion/file-preparation.html" style="color: blue; font-size: 20px;">VEDA docs for file naming conventions</a> -- Helps for understanding why/how we name content.

# %% [markdown]
# ## List of new 2nd level directories
#
#     "Sentinel-1"
#     "Sentinel-2"
#     "Landsat"
#     "MODIS"
#     "VIIRS"
#     "ASTER"
#     "MASTER"
#     "ECOSTRESS"
#     "Planet"
#     "Maxar"
#     "HLS"
#     "IMERG"
#     "GOES"
#     "SMAP"
#     "ICESat"
#     "GEDI"
#     "COMSAR"
#     "UAVSAR"
#     "WB-57"

# %%
# DO NOT CHANGE
DIR_OLD_BASE = 'drcs_activations'
DIR_NEW_BASE = 'drcs_activations_new'
BUCKET = 'nasa-disasters'

# %%
EVENT_NAME = '202301_Flood_CA'  #find the name within drcs_activations OLD Directory (see link above)
PRODUCT_NAME = 'sentinel1'      #find the name within drcs_activations OLD Directory (see link above)

RENAME_PRODUCT = 'Sentinel-1'   #choose from LIST of 2nd level directories (see above list)

PATH_OLD = f'{DIR_OLD_BASE}/{EVENT_NAME}/{PRODUCT_NAME}'  # Updated to use actual available directory
DIRECTORY_NEW = f'{DIR_NEW_BASE}/{RENAME_PRODUCT}'

# %% [markdown]
# ## Initialize AWS S3 Client with automatic credential detection

# %%
# Initialize AWS S3 Client using the imported function
s3_client, fs_read = initialize_s3_client(bucket_name=BUCKET, verbose=True)

# Verify S3 client is ready using the imported function
verify_s3_client(s3_client, bucket_name=BUCKET, verbose=True)

# Get all TIF files using the imported function
keys = get_all_s3_keys(s3_client, BUCKET, PATH_OLD, ".tif") if s3_client else []

if keys:
    print(f"✅ Found {len(keys)} .tif files in the S3 bucket.")
else:
    print("No keys found or S3 client not initialized")
    
keys
# Out:
# ⚠️ S3 client initialized (limited bucket list access)
# ✅ Confirmed access to nasa-disasters bucket
# ✅ S3 filesystem (fsspec) initialized
# ✅ S3 client ready for operations
#    Bucket: nasa-disasters
#    Ready to process files
# ✅ Found 114 .tif files in the S3 bucket.
# ['drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T015915_DVR_RTC30_G_gpufed_D7B8_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T015915_DVR_RTC30_G_gpufed_D7B8_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T015940_DVR_RTC30_G_gpufed_839D_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T015940_DVR_RTC30_G_gpufed_839D_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T020005_DVR_RTC30_G_gpufed_8349_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T020005_DVR_RTC30_G_gpufed_8349_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T135955_DVR_RTC30_G_gpufed_EDD5_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T135955_DVR_RTC30_G_gpufed_EDD5_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T140020_DVR_RTC30_G_gpufed_B46A_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230101T140020_DVR_RTC30_G_gpufed_B46A_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T020722_DVR_RTC30_G_gpufed_8185_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T020722_DVR_RTC30_G_gpufed_8185_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T020747_DVR_RTC30_G_gpufed_D8E5_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T020747_DVR_RTC30_G_gpufed_D8E5_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T020812_DVR_RTC30_G_gpufed_F00C_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T020812_DVR_RTC30_G_gpufed_F00C_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T020837_DVR_RTC30_G_gpufed_7706_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T020837_DVR_RTC30_G_gpufed_7706_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T140739_DVR_RTC30_G_gpufed_954D_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T140739_DVR_RTC30_G_gpufed_954D_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T140804_DVR_RTC30_G_gpufed_3C9E_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T140804_DVR_RTC30_G_gpufed_3C9E_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T140829_DVR_RTC30_G_gpufed_ECEA_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T140829_DVR_RTC30_G_gpufed_ECEA_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T140853_DVR_RTC30_G_gpufed_9620_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230106T140853_DVR_RTC30_G_gpufed_9620_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230108T015013_DVR_RTC30_G_gpufed_2AB5_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230108T015013_DVR_RTC30_G_gpufed_2AB5_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230108T015040_DVR_RTC30_G_gpufed_A569_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230108T015040_DVR_RTC30_G_gpufed_A569_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230108T135223_DVR_RTC30_G_gpufed_7C97_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230108T135223_DVR_RTC30_G_gpufed_7C97_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230108T135249_DVR_RTC30_G_gpufed_7CE5_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230108T135249_DVR_RTC30_G_gpufed_7CE5_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T021600_DVR_RTC30_G_gpufed_04E3_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T021600_DVR_RTC30_G_gpufed_04E3_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T021626_DVR_RTC30_G_gpufed_94FC_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T021626_DVR_RTC30_G_gpufed_94FC_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T021651_DVR_RTC30_G_gpufed_D505_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T021651_DVR_RTC30_G_gpufed_D505_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T141536_DVR_RTC30_G_gpufed_DA1B_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T141536_DVR_RTC30_G_gpufed_DA1B_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T141602_DVR_RTC30_G_gpufed_9090_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T141602_DVR_RTC30_G_gpufed_9090_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T141627_DVR_RTC30_G_gpufed_D1B4_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230111T141627_DVR_RTC30_G_gpufed_D1B4_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230113T015821_DVR_RTC30_G_gpufed_A455_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230113T015821_DVR_RTC30_G_gpufed_A455_rgb.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230113T015849_DVR_RTC30_G_gpufed_E150_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230113
tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230125T140044_DVR_RTC30_G_gpufed_B43A_WM.tif',
#  'drcs_activations/202301_Flood_CA/sentinel1/S1A_IW_20230125T140044_DVR_RTC30_G_gpufed_B43A_rgb.tif']

# %% [markdown]
# ## Load TIF Files from DRCS Data
# ### This may assist with diagnosing any issues that occur if no files are found in the code block above
#
# This cell loads the pre-analyzed DRCS activation data from `drcs_activations_tif_files.json` which contains a complete inventory of all .tif files in the NASA Disasters S3 bucket.
#
# The code will:
# 1. Load the JSON file containing the file inventory
# 2. Parse the `PATH_OLD` variable to find the corresponding directory
# 3. Extract all .tif filenames from that directory
# 4. Store them in `files_to_process` for later use

# %%
# # Load the pre-analyzed DRCS TIF files data using imported functions
# # The JSON path is relative to the notebook location
# json_path = Path('../../s3-crawler/drcs_activations_tif_files.json')

# # Load DRCS data
# drcs_data = load_drcs_data(json_path)

# if drcs_data:
#     # Get TIF files from the specified PATH_OLD using the imported function
#     tif_files = get_tif_files_from_path(PATH_OLD, drcs_data, DIR_OLD_BASE)
    
#     if tif_files:
#         print(f"\n📁 Found {len(tif_files)} .tif files in {PATH_OLD}:")
#         print("\nFirst 10 files:")
#         for i, file in enumerate(tif_files[:10], 1):
#             print(f"  {i:2d}. {file}")
#         if len(tif_files) > 10:
#             print(f"  ... and {len(tif_files) - 10} more files")
        
#         # Get files with full paths using the imported function
#         files_to_process = get_files_with_full_paths(PATH_OLD, drcs_data, DIR_OLD_BASE, json_path)
#         print(f"\n✅ Files ready for processing. Stored in 'files_to_process' variable.")
#     else:
#         print(f"\n❌ No files found. Please check the PATH_OLD variable.")
#         files_to_process = []
# else:
#     print(f"\n❌ Could not load DRCS data.")
#     files_to_process = []

# files_to_process

# %%
# # Example: List available activation events using the imported function
# print("📂 Available activation events in DRCS data:")
# events = list_available_directories('drcs_activations', drcs_data, json_path)

# # Show first 10 events
# for event in events[:10]:
#     print(f"  - {event}")
# if len(events) > 10:
#     print(f"  ... and {len(events) - 10} more events")

# # Example: List subdirectories for a specific event
# print(f"\n📁 Subdirectories in {EVENT_NAME}:")
# subdirs = list_available_directories(f'drcs_activations/{EVENT_NAME}', drcs_data, json_path)
# for subdir in subdirs:
#     print(f"  - {subdir}")

# %% [markdown]
# # For these we can see three different types of files
#
# 1. WM = water mask
# 2. rgb = red green blue
# 3. WM_diff = water mask difference between dates
#
# ### We are going to need 2 different directories for these!!!
#
# We will keep WaterMask (WM) and rgb as separate directories

# %%
# For simplicity, let's use python list comprehension to return the files
# We may need to rename them in different ways for different products
# We will do a similar process later

## NOTE --- We can actually use these objects since they have the same path as the s3 files. We will call them again later

water_mask = [f for f in keys if "_WM.tif" in f]
rgb = [f for f in keys if "rgb.tif" in f]
water_mask_diff = [f for f in keys if "WM_diff.tif" in f]

# %% [markdown]
# # Useful links
# <a href="https://data.disasters.openveda.cloud/browseui/browseui/#drcs_activations/" style="color: blue; font-size: 20px;">drcs_activations OLD Directory</a> -- You can view old directory file structure here.
#
# <a href="https://docs.openveda.cloud/user-guide/content-curation/dataset-ingestion/file-preparation.html" style="color: blue; font-size: 20px;">VEDA docs for file naming conventions</a> -- Helps for understanding why/how we name content.

# %%
config_WM = {
    "data_acquisition_method": "s3",
    "raw_data_bucket" : BUCKET, #DO NOT CHANGE
    "raw_data_prefix": PATH_OLD,
    "cog_data_bucket": BUCKET, #DO NOT CHANGE
    "cog_data_prefix": f"{DIRECTORY_NEW}/WM",  #We changed this!!!!!!!
    "local_output_dir": f"output/{EVENT_NAME}",  # Local directory to save COGs
    "transformation": {}
}

config_rgb = {
    "data_acquisition_method": "s3",
    "raw_data_bucket" : BUCKET, #DO NOT CHANGE
    "raw_data_prefix": PATH_OLD,
    "cog_data_bucket": BUCKET, #DO NOT CHANGE
    "cog_data_prefix": f"{DIRECTORY_NEW}/rgb", #We changed this!!!!!!!
    "local_output_dir": f"output/{EVENT_NAME}",  # Local directory to save COGs
    "transformation": {}
}

# %% [markdown]
# ## Configure bucket and paths (no need to create session manually)

# %%
def return_bucket_info(config):
    """
    Extract bucket information from configuration and return as dictionary.
    
    Args:
        config: Configuration dictionary containing bucket and prefix information
    
    Returns:
        Dictionary with bucket and prefix information
    """
    # Configure bucket and paths (no need to create session manually)
    bucket_name = config["cog_data_bucket"]
    raw_data_bucket = config["raw_data_bucket"]
    raw_data_prefix = config["raw_data_prefix"]
    
    cog_data_bucket = config['cog_data_bucket']
    cog_data_prefix = config["cog_data_prefix"]
    
    print(f"Configuration loaded:")
    print(f"  Source bucket: {raw_data_bucket}")
    print(f"  Source prefix: {raw_data_prefix}")
    print(f"  Target bucket: {cog_data_bucket}")
    print(f"  Target prefix: {cog_data_prefix}")

    return {
        "bucket_name": bucket_name,
        "raw_data_bucket": raw_data_bucket,
        "raw_data_prefix": raw_data_prefix,
        "cog_data_bucket": cog_data_bucket,
        "cog_data_prefix": cog_data_prefix
    }

# %%
# Use the function with config_WM
wm_bucket = return_bucket_info(config_WM)
rgb_bucket = return_bucket_info(config_rgb)
# Out:
# Configuration loaded:
#   Source bucket: nasa-disasters
#   Source prefix: drcs_activations/202301_Flood_CA/sentinel1
#   Target bucket: nasa-disasters
#   Target prefix: drcs_activations_new/Sentinel-1/WM
# Configuration loaded:
#   Source bucket: nasa-disasters
#   Source prefix: drcs_activations/202301_Flood_CA/sentinel1
#   Target bucket: nasa-disasters
#   Target prefix: drcs_activations_new/Sentinel-1/rgb

# %%
def convert_sentinel_datetime(datetime_str):
    """
    Convert Sentinel datetime format to ISO 8601 format with UTC timezone.
    
    Args:
        datetime_str: String like '20240430T002653'
    
    Returns:
        String like '2024-04-30T00:26:53Z'
    """
    # Extract components
    year = datetime_str[0:4]
    month = datetime_str[4:6]
    day = datetime_str[6:8]
    hour = datetime_str[9:11]
    minute = datetime_str[11:13]
    second = datetime_str[13:15]
    
    # Format with dashes and colons, add Z for UTC
    return f"{year}-{month}-{day}T{hour}:{minute}:{second}Z"

# Test
datetime_str = '20240430T002653'
result = convert_sentinel_datetime(datetime_str)
print(result)  # 2024-04-30T00:26:53Z
# Out:
# 2024-04-30T00:26:53Z

# %%
# f'{EVENT_NAME}_{"_".join(fsplit[0:2])}_{"_".join(fsplit[3:8])}_{convert_sentinel_datetime(fsplit[2])}.tif'

# %%
# Define COG profile for rasterio
COG_PROFILE = {
    "driver": "COG",
    "compress": "DEFLATE",
}

# %% [markdown]
# ## Define COG Conversion Function
#
# This function handles the conversion of files to Cloud Optimized GeoTIFFs with proper CRS and caching.

# %%
def convert_to_proper_CRS_and_cogify(name, cog_filename, cog_data_bucket, cog_data_prefix, local_output_dir=None):
    """
    Convert a file to Cloud Optimized GeoTIFF with proper CRS.
    
    This function includes:
    - Download caching to avoid re-downloading files
    - CRS reprojection to EPSG:4326
    - COG validation before upload
    - Upload to S3
    - Smart nodata value handling based on data type
    """
    s3_key = f"{cog_data_prefix}/{cog_filename}"
    reproject_filename = f"reproj/{cog_filename}"
    
    # Create necessary directories
    os.makedirs("reproj", exist_ok=True)
    
    # Create data_download directory for caching
    data_download_dir = "data_download"
    os.makedirs(data_download_dir, exist_ok=True)
    
    # Create subdirectory structure to match S3 path
    s3_path_parts = name.split('/')
    local_subdir = os.path.join(data_download_dir, *s3_path_parts[:-1])
    os.makedirs(local_subdir, exist_ok=True)
    
    # Local path for the downloaded file (persistent storage)
    local_download_path = os.path.join(data_download_dir, name)
    
    # Temporary file for processing
    temp_input_file = f"temp_{os.path.basename(name)}"

    try:
        # Check if file already exists locally
        if os.path.exists(local_download_path):
            print(f"   [CACHE HIT] Using cached file: {local_download_path}")
            import shutil
            shutil.copy(local_download_path, temp_input_file)
        else:
            # Download the file from S3
            print(f"   [DOWNLOAD] Downloading from S3...")
            s3_client.download_file(BUCKET, name, local_download_path)
            print(f"   [DOWNLOAD] ✅ Saved to cache")
            import shutil
            shutil.copy(local_download_path, temp_input_file)
        
        # Reproject to EPSG:4326
        print(f"   [REPROJECT] Converting to EPSG:4326...")
        with rasterio.open(temp_input_file) as src:
            dst_crs = "EPSG:4326"
            
            # Check if reprojection is needed
            if src.crs and src.crs.to_string() == dst_crs:
                print(f"   [REPROJECT] Already in {dst_crs}, skipping reprojection")
                import shutil
                shutil.copy(temp_input_file, reproject_filename)
            else:
                transform, width, height = calculate_default_transform(
                    src.crs, dst_crs, src.width, src.height, *src.bounds
                )
                kwargs = src.meta.copy()
                kwargs.update({
                    "driver": "COG",
                    "compress": "DEFLATE",
                    "crs": dst_crs,
                    "transform": transform,
                    "width": width,
                    "height": height
                })

                with rasterio.open(reproject_filename, "w", **kwargs) as dst:
                    for band_idx in range(1, src.count + 1):
                        reproject(
                            source=rasterio.band(src, band_idx),
                            destination=rasterio.band(dst, band_idx),
                            src_transform=src.transform,
                            src_crs=src.crs,
                            dst_transform=transform,
                            dst_crs=dst_crs,
                            resampling=Resampling.nearest,
                            wrapdateline=True
                        )

        # COGify & upload
        print(f"   [COGIFY] Creating COG...")
        ds = rxr.open_rasterio(reproject_filename)
        
        # Handle coordinate naming
        if "y" in ds.dims and "x" in ds.dims:
            ds = ds.rename({"y": "lat", "x": "lon"})
            ds.rio.set_spatial_dims("lon", "lat", inplace=True)
        
        # Smart nodata value handling based on data type
        print(f"   [NODATA] Data type: {ds.dtype}")
        if ds.dtype == 'uint8':
            # For RGB images (uint8), use 0 as nodata (black pixels)
            nodata_value = 0
            print(f"   [NODATA] Using nodata value {nodata_value} for uint8 data")
        elif ds.dtype == 'uint16':
            # For uint16, use 0 as nodata
            nodata_value = 0
            print(f"   [NODATA] Using nodata value {nodata_value} for uint16 data")
        else:
            # For float32, int16, int32, etc., use -9999
            nodata_value = -9999
            print(f"   [NODATA] Using nodata value {nodata_value} for {ds.dtype} data")
        
        ds.rio.write_nodata(nodata_value, inplace=True)

        with tempfile.NamedTemporaryFile(suffix='.tif', delete=False) as tmp:
            tmp_name = tmp.name
            ds.rio.to_raster(tmp_name, **COG_PROFILE)
            
            # Validate COG
            print(f"   [VALIDATE] Checking COG validity...")
            is_valid_cog, validation_details = validate_cog(tmp_name)
            
            if is_valid_cog:
                print(f"   [VALIDATE] ✅ Valid COG")
            else:
                print(f"   [VALIDATE] ⚠️ COG validation warnings")
                critical_errors = [e for e in validation_details['errors'] if 'Invalid driver' in e]
                if critical_errors:
                    raise ValueError(f"Critical COG validation failed")
                if 'errors' in validation_details:
                    for error in validation_details['errors']:
                        print(f"      - {error}")
                if 'warnings' in validation_details:
                    for warning in validation_details['warnings']:
                        print(f"      - {warning}")
            
            # Upload to S3
            print(f"   [UPLOAD] Uploading to S3...")
            s3_client.upload_file(
                Filename=tmp_name,
                Bucket=cog_data_bucket,
                Key=s3_key
            )
            print(f"   [SUCCESS] ✅ Uploaded to s3://{cog_data_bucket}/{s3_key}")
            
            # Save locally if specified
            if local_output_dir:
                os.makedirs(local_output_dir, exist_ok=True)
                local_path = os.path.join(local_output_dir, cog_filename)
                import shutil
                shutil.copy(tmp_name, local_path)
            
    except Exception as e:
        print(f"   [ERROR] Failed: {str(e)}")
        raise
            
    finally:
        # Clean up temporary files
        for temp_file in [temp_input_file, reproject_filename]:
            if os.path.exists(temp_file):
                os.remove(temp_file)
        if 'tmp_name' in locals() and os.path.exists(tmp_name):
            os.remove(tmp_name)

print("✅ COG conversion function defined with smart nodata handling")
# Out:
# ✅ COG conversion function defined with smart nodata handling

# %%
# Check current cache status using the imported function
check_cache_status()
# Out:
# 📁 Cache directory does not exist: data_download/
#    Creating cache directory...
# ✅ Cache directory created: data_download/
# (0, 0)

# %% [markdown]
# # Useful links
# <a href="https://data.disasters.openveda.cloud/browseui/browseui/#drcs_activations/" style="color: blue; font-size: 20px;">drcs_activations OLD Directory</a> -- You can view old directory file structure here.
#
# <a href="https://docs.openveda.cloud/user-guide/content-curation/dataset-ingestion/file-preparation.html" style="color: blue; font-size: 20px;">VEDA docs for file naming conventions</a> -- Helps for understanding why/how we name content.

# %% [markdown]
# # Process RGB files

# %%
# NOTE for the diff files, we need to add diff at the 1st date before it
# Otherwise VEDA will think that the first date is the most important

# Example S1_diff20240430_20240507_WM.tif

# %%
# Define filename creator functions for different file types

def create_cog_filename_WM(f, EVENT_NAME):
    """Create COG filename for water mask files."""
    f2 = Path(f).stem
    fsplit = f2.split('_')
    
    # Check if it's a diff file
    if "WM_diff" in f:
        # For diff files: S1_20240430_20240507_WM_diff.tif
        # Need to add "diff" before the first date
        # Result: S1_diff20240430_20240507_WM.tif
        return f'{EVENT_NAME}_S1_WM_diff{fsplit[1]}_{fsplit[2]}.tif'
    else:
        # Regular WM files
        cog_filename = f'{EVENT_NAME}_{"_".join(fsplit[0:2])}_{"_".join(fsplit[3:8])}_WM_{convert_sentinel_datetime(fsplit[2])}.tif'
        return cog_filename

def create_cog_filename_rgb(f, EVENT_NAME):
    """Create COG filename for RGB files."""
    f2 = Path(f).stem
    fsplit = f2.split('_')
    
    # For RGB files, similar to WM but keep rgb suffix in the output
    # Extract parts and rebuild with rgb indicator
    cog_filename = f'{EVENT_NAME}_{"_".join(fsplit[0:2])}_{"_".join(fsplit[3:8])}_rgb_{convert_sentinel_datetime(fsplit[2])}.tif'
    return cog_filename

def create_cog_filename_diff(f, EVENT_NAME):
    """Create COG filename for water mask diff files."""
    f2 = Path(f).stem
    fsplit = f2.split('_')
    
    # For diff files: S1_20240430_20240507_WM_diff.tif
    # Need to add "diff" before the first date
    # Result: 202405_Flood_TX_S1_diff20240430_20240507_WM.tif
    return f'{EVENT_NAME}_S1_WM_diff{fsplit[1]}_{fsplit[2]}.tif'

# Test functions
print("Testing WM filename:")
test_wm = create_cog_filename_WM('drcs_activations/202405_Flood_TX/sentinel1/S1A_IW_20240430T002653_DVR_RTC20_G_gpuned_0610_WM.tif', EVENT_NAME)
print(f"  {test_wm}")

print("\nTesting RGB filename:")
test_rgb = create_cog_filename_rgb('drcs_activations/202405_Flood_TX/sentinel1/S1A_IW_20240430T002653_DVR_RTC20_G_gpuned_0610_rgb.tif', EVENT_NAME)
print(f"  {test_rgb}")
# Out:
# Testing WM filename:
#   202301_Flood_CA_S1A_IW_DVR_RTC20_G_gpuned_0610_WM_2024-04-30T00:26:53Z.tif
#
# Testing RGB filename:
#   202301_Flood_CA_S1A_IW_DVR_RTC20_G_gpuned_0610_rgb_2024-04-30T00:26:53Z.tif

# %%
## Process files using batch processing function

print("📊 File categorization:")
print(f"  - Water mask files: {len(water_mask)}")
print(f"  - RGB files: {len(rgb)}")
print(f"  - Water mask diff files: {len(water_mask_diff)}")
print(f"  - Total files: {len(keys)}")



# Process water mask files
if water_mask:
    print("\n" + "="*50)
    print("🌊 Processing Water Mask Files")
    print("="*50)
    # Initialize combined results DataFrame
    all_files_processed = pd.DataFrame()
    
    wm_results = process_file_batch(
        file_list=water_mask,
        s3_client=s3_client,
        config=config_WM,
        filename_creator_func=create_cog_filename_WM,
        processing_func=convert_to_proper_CRS_and_cogify,
        event_name=EVENT_NAME,
        save_metadata=True,
        save_csv=True,
        verbose=True
    )
    all_files_processed = pd.concat([all_files_processed, wm_results], ignore_index=True)
    
    # Print overall summary
    print_batch_summary(all_files_processed)


# Process RGB files
if rgb:
    print("\n" + "="*50)
    print("🎨 Processing RGB Files")
    print("="*50)
    # Initialize combined results DataFrame
    all_files_processed = pd.DataFrame()
    
    rgb_results = process_file_batch(
        file_list=rgb,
        s3_client=s3_client,
        config=config_rgb,
        filename_creator_func=create_cog_filename_rgb,
        processing_func=convert_to_proper_CRS_and_cogify,
        event_name=EVENT_NAME,
        save_metadata=True,
        save_csv=True,
        verbose=True
    )
    all_files_processed = pd.concat([all_files_processed, rgb_results], ignore_index=True)
    
    # Print overall summary
    print_batch_summary(all_files_processed)
    
# Process water mask diff files
if water_mask_diff:
    print("\n" + "="*50)
    print("🔄 Processing Water Mask Diff Files")
    print("="*50)
    # Initialize combined results DataFrame
    all_files_processed = pd.DataFrame()
    
s3://nasa-disasters/drcs_activations_new/Sentinel-1/rgb/202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_B43A_rgb_2023-01-25T14:00:44Z.tif
#    ✅ Generated and saved COG: 202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_B43A_rgb_2023-01-25T14:00:44Z.tif
#
# ✅ Batch processing complete: 57 files processed
# 📊 Uploaded metadata to s3://nasa-disasters/drcs_activations_new/Sentinel-1/rgb/metadata.json
# 📝 Saved processing log to s3://nasa-disasters/drcs_activations_new/Sentinel-1/rgb/files_converted.csv
# 📁 COGs saved locally to: output/202301_Flood_CA
#
# ==================================================
# 📊 BATCH PROCESSING SUMMARY
# ==================================================
# Total files processed: 57
# Successful: 57
# Failed: 0
# Success rate: 100.0%
# Timestamp: 2025-09-03T16:55:07.582908
# ==================================================

# %%
# Display final results (for a single instance)
print(f"\n📊 Final Processing Results:")
print(f"Total files processed: {len(all_files_processed)}")
print(f"\nProcessed files DataFrame:")
all_files_processed
# Out:
# 📊 Final Processing Results:
# Total files processed: 57
#
# Processed files DataFrame:
#                                             file_name  \
# 0   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 1   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 2   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 3   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 4   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 5   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 6   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 7   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 8   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 9   drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 10  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 11  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 12  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 13  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 14  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 15  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 16  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 17  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 18  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 19  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 20  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 21  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 22  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 23  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 24  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 25  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 26  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 27  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 28  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 29  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 30  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 31  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 32  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 33  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 34  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 35  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 36  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 37  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 38  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 39  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 40  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 41  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 42  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 43  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 44  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 45  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 46  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 47  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 48  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 49  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 50  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 51  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 52  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 53  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 54  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 55  drcs_activations/202301_Flood_CA/sentinel1/S1A...
# 56  drcs_activations/202301_Flood_CA/sentinel1/S1A...
#
#                                          COGs_created
# 0   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_D7B8...
# 1   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_839D...
# 2   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_8349...
# 3   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_EDD5...
# 4   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_B46A...
# 5   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_8185...
# 6   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_D8E5...
# 7   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_F00C...
# 8   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_7706...
# 9   202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_954D...
# 10  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_3C9E...
# 11  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_ECEA...
# 12  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_9620...
# 13  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_2AB5...
# 14  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_A569...
# 15  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_7C97...
# 16  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_7CE5...
# 17  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_04E3...
# 18  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_94FC...
# 19  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_D505...
# 20  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_DA1B...
# 21  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_9090...
# 22  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_D1B4...
# 23  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_A455...
# 24  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_E150...
# 25  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_0477...
# 26  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_9C06...
# 27  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_D981...
# 28  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_BC0A...
# 29  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_52F3...
# 30  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_56F2...
# 31  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_CCF9...
# 32  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_CB27...
# 33  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_9709...
# 34  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_5953...
# 35  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_56B7...
# 36  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_6466...
# 37  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_54F0...
# 38  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_4331...
# 39  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_D441...
# 40  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_2E12...
# 41  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_E4BE...
# 42  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_01C5...
# 43  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_57F3...
# 44  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_042E...
# 45  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_557E...
# 46  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_3C7F...
# 47  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_9DAF...
# 48  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_30D7...
# 49  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_D5B2...
# 50  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_66F6...
# 51  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_B279...
# 52  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_E8F1...
# 53  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_FCEF...
# 54  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_8E2A...
# 55  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_B59B...
# 56  202301_Flood_CA_S1A_IW_DVR_RTC30_G_gpufed_B43A...

# %% [markdown]
# ## Check STATUS of file conversion and upload
#
# <a href="https://data.disasters.openveda.cloud/browseui/browseui/#drcs_activations_new/" style="color: blue; font-size: 20px;">Disasters Bucket</a> -- You can view that the files actually made it to their correct destination.
